# %% [markdown]
# # 1. library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
sns.set(style='white')
# %matplotplb inline
# Out:
# UsageError: Line magic function `%matplotplb` not found.

# %%
application = pd.read_csv('C:/Users/User/Desktop/application_record.csv')
credit = pd.read_csv('C:/Users/User/Desktop/credit_record.csv')

# %%
application
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
credit
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
application.shape
# Out:
# (438557, 18)

# %%
application.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
application.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
application.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# ...

# %% [markdown]
# # 2. Observation
#
# *아이가 19명인 이상치가 보입니다.*
#
# *수입 Max가 너무 크다*
#
# *DAYS_EMPLOYED max 너무 큼*
#
# *FAMLIY_MEMBERS 아이 max 큼*
#
# *occupation_type 결측치가 너무 많음*

# %%
application.shape
# Out:
# (438557, 18)

# %%
credit.shape
# Out:
# (1048575, 3)

# %%
application.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
credit.isnull().sum()
# Out:
# ID                0
# MONTHS_BALANCE    0
# STATUS            0
# dtype: int64

# %%
application.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %% [markdown]
# # 3. 특성가공
#
# *merge로 application과 credit 데이터 합침*

# %%
application = application.drop(['OCCUPATION_TYPE'], axis=1)

# %%
application.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
application.shape
# Out:
# (438557, 17)

# %%
# /데이터 정리

application['NAME_EDUCATION_TYPE'] = application['NAME_EDUCATION_TYPE'].str.split('/',expand=True)[0]
application['NAME_HOUSING_TYPE'] = application['NAME_HOUSING_TYPE'].str.split('/',expand=True)[0]

# %%
application.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 0          427500.0               Working    Higher education
# 1          427500.0               Working    Higher education
# 2          112500.0               Working          Secondary
# 3          270000.0  Commercial associate          Secondary
# 4          270000.0  Commercial associate          Secondary
#
#      NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage  Rented apartment      -12005          -4542
# ...

# %% [markdown]
# *name_education_type 정리- secondary는 중등 교육, higher education 고등 교육*

# %%
#AGE
application['AGE']= round(-(application['DAYS_BIRTH']/365),0)
application['AGE'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
application['NAME_EDUCATION_TYPE'].value_counts()
# Out:
# Secondary            301821
# Higher education     117522
# Incomplete higher     14851
# Lower secondary        4051
# Academic degree         312
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %%
application['NAME_FAMILY_STATUS'].unique()
# Out:
# array(['Civil marriage', 'Married', 'Single / not married', 'Separated',
#        'Widow'], dtype=object)

# %% [markdown]
# * int 데이터로 변형*
#
# * 불균형 데이터에 대한 처리 필요*

# %% [markdown]
# # 5.가공

# %%
data_set = application.merge(credit)

# %%
data_set
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# ...

# %%
data_set[data_set['NAME_FAMILY_STATUS']=='Civil marriage']=1
data_set[data_set['NAME_FAMILY_STATUS']=='Married']=1
data_set[data_set['NAME_FAMILY_STATUS']=='Single / not married']=0
data_set[data_set['NAME_FAMILY_STATUS']=='Separated']=0
data_set[data_set['NAME_FAMILY_STATUS']=='Widow']=0

# %%
data_set['NAME_FAMILY_STATUS'].unique()
# Out:
# array([1, 0], dtype=object)

# %%
data_set = data_set.drop(['ID','DAYS_BIRTH'], axis=1)

# %%
data_set.shape
# Out:
# (777715, 18)

# %% [markdown]
# # 모델링

# %%
train = data_set.copy()[:24305]
test = data_set.copy()[24305:]
target = test['STATUS']
test.drop(['STATUS'],axis=1, inplace=True)

# %%
X = train.drop(['STATUS'],axis=1)
y = train['STATUS']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=.3, random_state=42)

# %%
cat_cols = X_train.select_dtypes(include='object').columns.tolist()

# %%
# 레이블 인코딩 더미
# 부스팅 계열은 레이블 인코딩을 사용해도 괜찮음

le = LabelEncoder()

for i in cat_cols:
    X_train[i]=le.fit_transform(X_train[i])
    X_test[i]=le.transform(X_test[i]) #진짜 중요!!!
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_17000/3104039519.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[i]=le.fit_transform(X_train[i])
# C:\Users\User\AppData\Local\Temp/ipykernel_17000/3104039519.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[i]=le.transform(X_test[i]) #진짜 중요!!!

# %% [markdown]
# 레이블 인코딩 - 인코딩된 수에 대해서 가중치가 부여된다.
#
#
# 오디너리 인코딩 - 데이터를 처음부터 끝까지 보는 가장 처음 것을 0으로 새로운 것을 1 012345를 클래스 갯수 만큼 친다. 오디너리 인코딩은 숫자 크기에 대해서 연연하지 않고, 구분을 위해 숫자를 사용

# %%
from lightgbm import LGBMClassifier

# %%
clf = LGBMClassifier(random_state=42)
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17000/3823905253.py in <module>
#       1 clf = LGBMClassifier(random_state=42)
# ----> 2 clf.fit(X_train,y_train)
#       3 pred = clf.predict(X_test)
#       4 accuracy_score(y_test, pred)
#
# C:\User\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     921         """Docstring is inherited from the LGBMModel."""
#     922         _LGBMAssertAllFinite(y)
# --> 923         _LGBMCheckClassificationTargets(y)
#     924         self._le = _LGBMLabelEncoder().fit(y)
#     925         _y = self._le.transform(y)
#
# ...
